# %% [markdown]
# <table>
#   <tr>
#     <td style="text-align: center;">
#       <img src="./images/pandas.png" alt="Pandas Logo"  style="margin-bottom: 80px;"/><br>
#       <a href="https://pandas.pydata.org/docs/" target="_blank" style="text-decoration: none; color: black; font-weight: bold;">Pandas</a>
#     </td>
#     <td style="text-align: center;">
#       <img src="./images/seaborn.svg" alt="Seaborn Logo"  style="margin-bottom: 80px;" /><br>
#       <a href="https://seaborn.pydata.org/api.html" target="_blank" style="text-decoration: none; color: black; font-weight: bold;">Seaborn</a>
#     </td>
#     <td style="text-align: center;">
#       <img src="./images/Plotly-logo.png" alt="Plotly Logo"  style="margin-bottom: 80px;" /><br>
#       <a href="https://plotly.com/python-api-reference/" target="_blank" style="text-decoration: none; color: black; font-weight: bold;">Plotly</a>
#     </td>
#     <td style="text-align: center;">
#       <img src="./images/altair-logo-light.png" alt="Altair Logo" style="margin-bottom: 50px;"/><br>
#       <a href="https://altair-viz.github.io/documentation/" target="_blank" style="text-decoration: none; color: black; font-weight: bold;">Altair</a>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ##   Introduction aux Diagrammes à Barres
#
# Les diagrammes à barres sont un outil de visualisation fondamental utilisé pour afficher des données catégorielles avec des barres rectangulaires. La longueur de chaque barre est proportionnelle à la valeur qu'elle représente. Les diagrammes à barres sont excellents pour comparer des quantités entre différentes catégories.
#
# **Quand utiliser les diagrammes à barres :**
#
# * Comparaison de données catégorielles.
# * Affichage de la fréquence ou du nombre de différentes catégories.
# * Visualisation des tendances entre les catégories.
#
# **Terminologie de base :**
#
# * Barres : Les colonnes rectangulaires représentant les valeurs des données.
# * Axes : Les lignes horizontales (axe des x) et verticales (axe des y) qui définissent le graphique.
# * Étiquettes : Le texte qui décrit les catégories et les valeurs.
# * Titre : La description générale du graphique.

# %% [markdown]
# <hr style="border: 2px solid black;">

# %% [markdown]
# ## Exercice : Analyse de Diamants avec les Bibliothèques de Visualisation
#
# Avant de commencer cet exercice, veuillez lire la documentation des bibliothèques suivantes pour vous familiariser avec leurs fonctionnalités de base :
#
# * Matplotlib : [https://matplotlib.org/](https://matplotlib.org/)
# * Seaborn : [https://seaborn.pydata.org/](https://seaborn.pydata.org/)
# * Plotly : [https://plotly.com/python/](https://plotly.com/python/)
# * Altair : [https://altair-viz.github.io/](https://altair-viz.github.io/)
#
# Vous disposez d'un ensemble de données contenant des informations sur divers diamants. Votre tâche est de réaliser l'analyse et les visualisations suivantes en utilisant Matplotlib, Seaborn, Plotly et Altair. Pour chaque visualisation, fournissez un bref commentaire sur ce que vous observez concernant les forces et les faiblesses de chaque bibliothèque pour cette tâche particulière.
#
# 1.  **Chargement et Inspection des Données :**
#
#     * Chargez l'ensemble de données à partir de l'URL fourni : `"https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv"`
#     * Affichez les 5 premières lignes de l'ensemble de données pour comprendre sa structure.
#     * Imprimez les noms des colonnes et leurs types de données.
#     * Affichez les 10 premières lignes de l'ensemble de données.
#
# 2.  **Visualisation par Diagramme à Barres :**
#
#     * **Matplotlib :**
#         * Créez un diagramme à barres pour visualiser le nombre de diamants pour chaque catégorie de 'cut' en utilisant Matplotlib.
#         * Personnalisez ce diagramme à barres en ajoutant des étiquettes appropriées pour l'axe des x et l'axe des y, et définissez un titre pour le graphique.
#         * Commentez la syntaxe de Matplotlib, ses capacités de personnalisation et sa facilité d'utilisation pour cette tâche.
#     * **Seaborn :**
#         * Créez le même diagramme à barres (nombre de diamants par 'cut') en utilisant Seaborn.
#         * Personnalisez le graphique comme vous l'avez fait avec Matplotlib (étiquettes, titre).
#         * Comparez le code de Seaborn à celui de Matplotlib. Qu'est-ce que Seaborn fait différemment ou plus facilement ? Comment le style par défaut se compare-t-il ?
#     * **Plotly :**
#         * Créez un diagramme à barres interactif (nombre de diamants par 'cut') en utilisant Plotly.
#         * Personnalisez le graphique avec des étiquettes et un titre. Explorez les fonctionnalités d'interactivité de Plotly (info-bulles, zoom).
#         * Commentez l'interactivité de Plotly, sa syntaxe et en quoi elle diffère de Matplotlib et Seaborn.
#     * **Altair :**
#         * Créez un diagramme à barres (nombre de diamants par 'cut') en utilisant Altair.
#         * Personnalisez le graphique avec des étiquettes et un titre.
#         * Commentez la syntaxe déclarative d'Altair et comment elle se compare aux autres bibliothèques.
#
# 3.  **Analyse Supplémentaire (Facultatif) :**
#
#     * Explorez davantage les données en créant des diagrammes à barres pour d'autres variables catégorielles telles que 'color' ou 'clarity' dans n'importe laquelle des bibliothèques.
#     * Essayez de visualiser le prix moyen pour chaque 'cut' ou 'color' en utilisant les différentes bibliothèques et commentez la façon dont chaque bibliothèque gère ce type d'agrégation.
#
# **Conseils :**
#
# * Utilisez la bibliothèque pandas pour charger et manipuler les données.
# * Utilisez les bibliothèques Matplotlib, Seaborn, Plotly et Altair pour créer les diagrammes à barres.
# * Référez-vous au notebook pour des exemples de code et des explications sur les fonctions dont vous pourriez avoir besoin.

# %%
# =====================================================
# 1. Chargement et Inspection des Données
# =====================================================
import pandas as pd
import numpy as np

diamonds_url = "https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv"
diamonds_df = pd.read_csv(diamonds_url)

# Afficher les 5 premières lignes
print("=== 5 premières lignes ===")
diamonds_df.head()

# %%
# Noms des colonnes et types de données
print("=== Colonnes et types de données ===")
print(diamonds_df.dtypes)
print(f"\nNombre de lignes: {len(diamonds_df)}, Nombre de colonnes: {len(diamonds_df.columns)}")

# %%
# Afficher les 10 premières lignes
print("=== 10 premières lignes ===")
diamonds_df.head(10)

# %% [markdown]
# ## 2. Visualisation par Diagramme à Barres
#
# ### 2.1 Matplotlib
#
# **Commentaire :**
# - Syntaxe verbeuse : il faut d'abord calculer `value_counts()` soi-même, puis appeler `ax.bar()`, puis configurer chaque label un par un.
# - Par contre on contrôle tout : couleurs des barres, taille de la figure, espacement, etc.
# - On voit clairement qu'Ideal domine (~21k diamants), Fair est la catégorie la plus rare (~1600). L'ordre des barres dépend de `value_counts()` qui trie par fréquence décroissante par défaut.
# - Pour un barplot simple comme celui-ci, c'est beaucoup de code pour pas grand chose.

# %%
# =====================================================
# 2.1 Diagramme à barres avec Matplotlib
# =====================================================
import matplotlib.pyplot as plt

# Compter le nombre de diamants par catégorie de cut
cut_counts = diamonds_df['cut'].value_counts()

# Créer le diagramme à barres
fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(cut_counts.index, cut_counts.values, color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd'])
ax.set_xlabel('Qualité de la Taille (Cut)')
ax.set_ylabel('Nombre de Diamants')
ax.set_title('Nombre de Diamants par Catégorie de Cut - Matplotlib')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.2 Seaborn
#
# **Commentaire :**
# - `sns.countplot()` fait le `value_counts()` tout seul, pas besoin de pré-calculer. Ça raccourcit le code.
# - Le paramètre `order` permet de forcer l'ordre logique (Fair → Ideal) au lieu du tri par fréquence.
# - Style par défaut plus soigné que Matplotlib brut : palette de couleurs harmonieuse, grille en fond.
# - Pour la personnalisation poussée (genre annoter chaque barre avec sa valeur), on retombe quand même sur du code Matplotlib classique via l'objet `ax`.

# %%
# =====================================================
# 2.2 Diagramme à barres avec Seaborn
# =====================================================
import seaborn as sns

fig, ax = plt.subplots(figsize=(8, 5))
sns.countplot(data=diamonds_df, x='cut', 
              order=['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],
              palette='viridis', ax=ax)
ax.set_xlabel('Qualité de la Taille (Cut)')
ax.set_ylabel('Nombre de Diamants')
ax.set_title('Nombre de Diamants par Catégorie de Cut - Seaborn')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3 Plotly
#
# **Commentaire :**
# - Le gros plus : le graphique est interactif. On peut survoler chaque barre pour voir le nombre exact de diamants, zoomer, etc. Pas besoin de code en plus pour ça.
# - La syntaxe `px.bar()` est très courte, comparable à Seaborn.
# - Par contre il faut quand même pré-calculer les counts avec pandas (contrairement à Seaborn qui le fait tout seul).
# - Le graphique est rendu en HTML/JS donc plus lourd qu'une image matplotlib. Pas adapté pour un rapport PDF, mais top pour un dashboard ou une présentation.

# %%
# =====================================================
# 2.3 Diagramme à barres interactif avec Plotly
# =====================================================
import plotly.express as px

# Compter le nombre de diamants par cut
cut_counts_df = diamonds_df['cut'].value_counts().reset_index()
cut_counts_df.columns = ['cut', 'count']

# Ordonner les catégories
cut_order = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
cut_counts_df['cut'] = pd.Categorical(cut_counts_df['cut'], categories=cut_order, ordered=True)
cut_counts_df = cut_counts_df.sort_values('cut')

fig = px.bar(cut_counts_df, x='cut', y='count',
             color='cut',
             labels={'cut': 'Qualité de la Taille (Cut)', 'count': 'Nombre de Diamants'},
             title='Nombre de Diamants par Catégorie de Cut - Plotly')
fig.update_layout(xaxis_title='Qualité de la Taille (Cut)',
                  yaxis_title='Nombre de Diamants')
fig.show()

# %% [markdown]
# ### 2.4 Altair
#
# **Commentaire :**
# - Approche déclarative : on dit "je veux des barres, x = cut, y = count" et Altair se débrouille. Pas besoin de pré-calculer les counts, `count()` est directement dans l'encodage.
# - Le code est très lisible, presque comme du pseudo-code.
# - Graphique interactif par défaut (tooltips).
# - Limitation : Altair plante au-delà de 5000 lignes sans `vegafusion` ou `alt.data_transformers.disable_max_rows()`. Ici le dataset fait ~54k lignes donc c'est obligatoire.
# - Visuellement le résultat est propre, comparable à Seaborn.

# %%
# =====================================================
# 2.4 Diagramme à barres avec Altair
# =====================================================
import altair as alt

# Altair a une limite par défaut de 5000 lignes, on la désactive
alt.data_transformers.enable('vegafusion')

chart = alt.Chart(diamonds_df).mark_bar().encode(
    x=alt.X('cut:N', title='Qualité de la Taille (Cut)',
            sort=['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']),
    y=alt.Y('count():Q', title='Nombre de Diamants'),
    color=alt.Color('cut:N', legend=alt.Legend(title='Cut')),
    tooltip=['cut:N', 'count():Q']
).properties(
    title='Nombre de Diamants par Catégorie de Cut - Altair',
    width=500,
    height=350
)

chart

# %% [markdown]
# ---
#
# ## 3. Analyse Supplémentaire (Bonus)
#
# ### Prix moyen par catégorie de Cut avec Plotly
#
# **Commentaire :**
# - J'ai choisi Plotly pour l'interactivité (on peut lire le prix exact au survol).
# - L'agrégation (moyenne par cut) est faite en pandas avec `groupby().mean()` avant de passer à Plotly. Plotly ne gère pas l'agrégation tout seul (contrairement à Altair qui peut faire `mean()` dans l'encodage).
# - Résultat intéressant : les diamants Fair ont un prix moyen plus élevé que les Ideal. C'est contre-intuitif, mais ça s'explique par le fait que les Fair sont souvent de gros carats (donc chers), alors que les Ideal incluent beaucoup de petits diamants qui tirent la moyenne vers le bas.

# %%
# =====================================================
# 3. Analyse Supplémentaire : Prix moyen par Cut
# =====================================================

# Agrégation avec pandas
avg_price_by_cut = diamonds_df.groupby('cut')['price'].mean().reset_index()
avg_price_by_cut.columns = ['cut', 'avg_price']

# Ordonner les catégories
cut_order = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
avg_price_by_cut['cut'] = pd.Categorical(avg_price_by_cut['cut'], categories=cut_order, ordered=True)
avg_price_by_cut = avg_price_by_cut.sort_values('cut')

# Visualisation avec Plotly
fig = px.bar(avg_price_by_cut, x='cut', y='avg_price',
             color='cut',
             labels={'cut': 'Qualité de la Taille (Cut)', 'avg_price': 'Prix Moyen (USD)'},
             title='Prix Moyen des Diamants par Catégorie de Cut - Plotly',
             text='avg_price')
fig.update_traces(texttemplate='$%{text:.0f}', textposition='outside')
fig.update_layout(xaxis_title='Qualité de la Taille (Cut)',
                  yaxis_title='Prix Moyen (USD)',
                  showlegend=False)
fig.show()
